# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Importing Data
# ### Cleaning the data

# %%
X = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
X = X.drop(["id","screen_time_hours_per_day","ethnicity","education_level","income_level","employment_status","diagnosed_diabetes"],axis=1)
y = X.iloc[:,-1]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700000 entries, 0 to 699999
# Data columns (total 19 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   age                                 700000 non-null  int64
#  1   alcohol_consumption_per_week        700000 non-null  int64
#  2   physical_activity_minutes_per_week  700000 non-null  int64
#  3   diet_score                          700000 non-null  float64
#  4   sleep_hours_per_day                 700000 non-null  float64
#  5   bmi                                 700000 non-null  float64
#  6   waist_to_hip_ratio                  700000 non-null  float64
#  7   systolic_bp                         700000 non-null  int64
#  8   diastolic_bp                        700000 non-null  int64
#  9   heart_rate                          700000 non-null  int64
#  10  cholesterol_total                   700000 non-null  int64
#  11  hdl_cholesterol                     700000 non-null  int64
#  12  ldl_cholesterol                     700000 non-null  int64
#  13  triglycerides                       700000 non-null  int64
#  14  gender                              700000 non-null  object
#  15  smoking_status                      700000 non-null  object
#  16  family_history_diabetes             700000 non-null  int64
#  17  hypertension_history                700000 non-null  int64
#  18  cardiovascular_history              700000 non-null  int64
# dtypes: float64(4), int64(13), object(2)
# memory usage: 101.5+ MB

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 700000 entries, 0 to 699999
# Series name: cardiovascular_history
# Non-Null Count   Dtype
# --------------   -----
# 700000 non-null  int64
# dtypes: int64(1)
# memory usage: 5.3 MB

# %%
X
# Out:
#         age  alcohol_consumption_per_week  physical_activity_minutes_per_week  \
# 0        31                             1                                  45
# 1        50                             2                                  73
# 2        32                             3                                 158
# 3        54                             3                                  77
# 4        54                             1                                  55
# ...     ...                           ...                                 ...
# 699995   29                             1                                  59
# 699996   46                             2                                  72
# 699997   35                             1                                  50
# 699998   49                             2                                  70
# 699999   42                             4                                  56
#
#         diet_score  sleep_hours_per_day   bmi  waist_to_hip_ratio  \
# 0              7.7                  6.8  33.4                0.93
# 1              5.7                  6.5  23.8                0.83
# 2              8.5                  7.4  24.1                0.83
# 3              4.6                  7.0  26.6                0.83
# 4              5.7                  6.2  28.8                0.90
# ...            ...                  ...   ...                 ...
# 699995         6.9                  5.2  26.1                0.88
# 699996         7.7                  7.7  25.5                0.85
# 699997         5.6                  6.1  26.9                0.88
# 699998         5.7                  6.9  25.2                0.86
# 699999         4.2                  7.0  28.3                0.90
#
#         systolic_bp  diastolic_bp  heart_rate  cholesterol_total  \
# 0               112            70          62                199
# 1               120            77          71                199
# 2                95            89          73                188
# 3               121            69          74                182
# 4               108            60          85                206
# ...             ...           ...         ...                ...
# 699995          133            57          69                163
# 699996          106            85          65                188
# 699997          127            84          63                168
# 699998          116            67          69                198
# 699999           99            73          74                191
#
#         hdl_cholesterol  ldl_cholesterol  triglycerides  gender  \
# 0                    58              114            102  Female
# 1                    50              121            124  Female
# 2                    59              114            108    Male
# 3                    54               85            123  Female
# 4                    49              131            124    Male
# ...                 ...              ...            ...     ...
# 699995               58               90            126  Female
# 699996               45              107            119  Female
# 699997               59               77            166  Female
# 699998               55              108            133  Female
# 699999               63              105            159  Female
#
#        smoking_status  family_history_diabetes  hypertension_history  \
# 0             Current                        0                     0
# 1               Never                        0                     0
# 2               Never                        0                     0
# 3             Current                        0                     1
# 4               Never                        0                     1
# ...               ...                      ...                   ...
# 699995         Former                        0                     0
# 699996         Former                        0                     0
# 699997          Never                        0                     0
# 699998          Never                        0                     0
# 699999         Former                        0                     0
#
#         cardiovascular_history
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0
# ...                        ...
# 699995                       0
# 699996                       1
# 699997                       0
# 699998                       0
# 699999                       0
#
# [700000 rows x 19 columns]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 699995    0
# 699996    1
# 699997    0
# 699998    0
# 699999    0
# Name: cardiovascular_history, Length: 700000, dtype: int64

# %% [markdown]
# ### Feature Engineering

# %%
from sklearn.compose import ColumnTransformer 
from sklearn.preprocessing import OneHotEncoder , StandardScaler 
from sklearn.pipeline import Pipeline 
from sklearn.linear_model import LogisticRegression

num_cols = ["age","alcohol_consumption_per_week","physical_activity_minutes_per_week","diet_score",
            'sleep_hours_per_day',
            "bmi","waist_to_hip_ratio","systolic_bp","diastolic_bp",
            "heart_rate","cholesterol_total","hdl_cholesterol","ldl_cholesterol","triglycerides"]
cat_cols = [
    'gender',
    'smoking_status'
]
bin_cols = ['family_history_diabetes','hypertension_history','cardiovascular_history']




preprocess = ColumnTransformer(
    transformers=[
        ("num",StandardScaler(),num_cols),
        ("cat",OneHotEncoder(),cat_cols),
        ("bin","passthrough",bin_cols)
    ]
)

model = Pipeline(
    steps=[
        ("pre",preprocess),
        ("log_reg",LogisticRegression(max_iter=1000,class_weight="balanced"))
    ]
)
model.fit(X,y)
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['age',
#                                                    'alcohol_consumption_per_week',
#                                                    'physical_activity_minutes_per_week',
#                                                    'diet_score',
#                                                    'sleep_hours_per_day', 'bmi',
#                                                    'waist_to_hip_ratio',
#                                                    'systolic_bp',
#                                                    'diastolic_bp', 'heart_rate',
#                                                    'cholesterol_total',
#                                                    'hdl_cholesterol',
#                                                    'ldl_cholesterol',
#                                                    'triglycerides']),
#                                                  ('cat', OneHotEncoder(),
#                                                   ['gender', 'smoking_status']),
#                                                  ('bin', 'passthrough',
#                                                   ['family_history_diabetes',
#                                                    'hypertension_history',
#                                                    'cardiovascular_history'])])),
#                 ('log_reg',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
model.predict(test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(300000,))

# %%
sample = pd.read_csv("sample_submission.csv")
sample.iloc[:,-1] = model.predict(test)
sample
# Out:
#             id  diagnosed_diabetes
# 0       700000                   0
# 1       700001                   0
# 2       700002                   0
# 3       700003                   0
# 4       700004                   0
# ...        ...                 ...
# 299995  999995                   0
# 299996  999996                   0
# 299997  999997                   0
# 299998  999998                   0
# 299999  999999                   0
#
# [300000 rows x 2 columns]

# %%
sample.to_csv("sample_submission.csv",index=False)
